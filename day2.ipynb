# %%
count = 0 
while count<5:
    print(count) 
    count=count+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10):
  if i==5:
    break
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10):
 if i%2==0:
   continue
 print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(3):
   for j in range(2):
      print(f"i:{i}and j:{j}" )
# Out:
# i:0and j:0
# i:0and j:1
# i:1and j:0
# i:1and j:1
# i:2and j:0
# i:2and j:1

# %%
for i in range (1,100):
    if i > 1 : 
        for j in range(2,i):
            if i%j==0:
                break 
            else:
                print(i)
# Out:
# 3
# 5
# 5
# 5
# 7
# 7
# 7
# 7
# 7
# 9
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 15
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 21
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 25
# 25
# 25
# 27
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 33
# 35
# 35
# 35
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 39
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# ...
